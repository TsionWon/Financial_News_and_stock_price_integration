# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import nltk
from nltk.corpus import stopwords
from datetime import datetime 
import yfinance as yf
import plotly.express as px

# %%
# Path to your CSV file
csv_file = r"C:\Users\Tsi\Desktop\10academy\.gitignore\raw_analyst_ratings.csv"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(csv_file)

# Display the DataFrame
print(df)
# Out:
#          Unnamed: 0                                           headline  \
# 0                 0            Stocks That Hit 52-Week Highs On Friday
# 1                 1         Stocks That Hit 52-Week Highs On Wednesday
# 2                 2                      71 Biggest Movers From Friday
# 3                 3       46 Stocks Moving In Friday's Mid-Day Session
# 4                 4  B of A Securities Maintains Neutral on Agilent...
# ...             ...                                                ...
# 1407323     1413844             Top Narrow Based Indexes For August 29
# 1407324     1413845  Recap: Wednesday's Top Percentage Gainers and ...
# 1407325     1413846  UPDATE: Oppenheimer Color on China Zenix Auto ...
# 1407326     1413847  Oppenheimer Initiates China Zenix At Outperfor...
# 1407327     1413848  China Zenix Auto International Opens For Tradi...
#
#                                                        url          publisher  \
# ...

# %%
df.head()
# Out:
#    Unnamed: 0                                           headline  \
# 0           0            Stocks That Hit 52-Week Highs On Friday
# 1           1         Stocks That Hit 52-Week Highs On Wednesday
# 2           2                      71 Biggest Movers From Friday
# 3           3       46 Stocks Moving In Friday's Mid-Day Session
# 4           4  B of A Securities Maintains Neutral on Agilent...
#
#                                                  url          publisher  \
# 0  https://www.benzinga.com/news/20/06/16190091/s...  Benzinga Insights
# 1  https://www.benzinga.com/news/20/06/16170189/s...  Benzinga Insights
# 2  https://www.benzinga.com/news/20/05/16103463/7...         Lisa Levin
# 3  https://www.benzinga.com/news/20/05/16095921/4...         Lisa Levin
# 4  https://www.benzinga.com/news/20/05/16095304/b...         Vick Meyer
#
#                         date stock
# 0  2020-06-05 10:30:54-04:00     A
# 1  2020-06-03 10:45:20-04:00     A
# ...

# %%
symbols = df["stock"].unique()

# %%
len(symbols)
# Out:
# 6204

# %%
symbols[:15]
# Out:
# array(['A', 'AA', 'AAC', 'AADR', 'AAL', 'AAMC', 'AAME', 'AAN', 'AAOI',
#        'AAON', 'AAP', 'AAPL', 'AAU', 'AAV', 'AAVL'], dtype=object)

# %%
# Define the ticker symbol
symbol = 'AAPL'

# %%
print(data.columns)
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits'], dtype='object')

# %%
a = yf.Ticker('A')

# %%
data = a.history(period='max')

# %%
# Create a Ticker object
ticker = yf.Ticker(symbol)

# %%
# Retrieve historical data
datam = ticker.history(period='max')

# %%
fig = px.line(data, x = data.index, y = data.Close, title='A Stock Analysis')
fig.show()

# %%
# # Convert the 'date' column to datetime objects to Prepare the Data
df['date'] = pd.to_datetime(df['date'], format='ISO8601')

# %%
a = yf.Ticker("A")


a
# Out:
# yfinance.Ticker object <A>

# %%
# get all stock info
a.info
# Out:
# {'address1': '5301 Stevens Creek Boulevard',
#  'city': 'Santa Clara',
#  'state': 'CA',
#  'zip': '95051',
#  'country': 'United States',
#  'phone': '800 227 9770',
#  'fax': '866 497 1134',
#  'website': 'https://www.agilent.com',
#  'industry': 'Diagnostics & Research',
#  'industryKey': 'diagnostics-research',
#  'industryDisp': 'Diagnostics & Research',
#  'sector': 'Healthcare',
#  'sectorKey': 'healthcare',
#  'sectorDisp': 'Healthcare',
# ...

# %%
# get historical market data
hist = a.history(period="max")

# %%
hist.head()
# Out:
#                                 Open       High        Low      Close  \
# Date
# 1999-11-18 00:00:00-05:00  27.560998  30.286814  24.229450  26.652395
# 1999-11-19 00:00:00-05:00  26.008803  26.046663  24.115879  24.456606
# 1999-11-22 00:00:00-05:00  25.024478  26.652395  24.267308  26.652395
# 1999-11-23 00:00:00-05:00  25.743787  26.425241  24.229446  24.229446
# 1999-11-24 00:00:00-05:00  24.305163  25.403061  24.229445  24.873041
#
#                              Volume  Dividends  Stock Splits
# Date
# 1999-11-18 00:00:00-05:00  62546380        0.0           0.0
# 1999-11-19 00:00:00-05:00  15234146        0.0           0.0
# 1999-11-22 00:00:00-05:00   6577870        0.0           0.0
# 1999-11-23 00:00:00-05:00   5975611        0.0           0.0
# 1999-11-24 00:00:00-05:00   4843231        0.0           0.0

# %%
hist.tail()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2024-04-29 00:00:00-04:00  138.259995  139.869995  137.880005  139.589996
# 2024-04-30 00:00:00-04:00  138.600006  139.649994  136.970001  137.039993
# 2024-05-01 00:00:00-04:00  136.720001  140.559998  136.130005  138.690002
# 2024-05-02 00:00:00-04:00  139.229996  139.889999  136.710007  137.520004
# 2024-05-03 00:00:00-04:00  139.690002  140.949997  138.410004  139.449997
#
#                             Volume  Dividends  Stock Splits
# Date
# 2024-04-29 00:00:00-04:00   781200        0.0           0.0
# 2024-04-30 00:00:00-04:00  1087300        0.0           0.0
# 2024-05-01 00:00:00-04:00   850400        0.0           0.0
# 2024-05-02 00:00:00-04:00  1146800        0.0           0.0
# 2024-05-03 00:00:00-04:00  1097529        0.0           0.0

# %%
fig = px.line(hist, x = hist.index, y = [hist.Close,hist.Open,hist.High,hist.Low], title='A Stock Analysis')
fig.show()

# %%
# show meta information about the history (requires history() to be called first)
a.history_metadata
# Out:
# {'currency': 'USD',
#  'symbol': 'A',
#  'exchangeName': 'NYQ',
#  'fullExchangeName': 'NYSE',
#  'instrumentType': 'EQUITY',
#  'firstTradeDate': 942935400,
#  'regularMarketTime': 1714766401,
#  'hasPrePostMarketData': True,
#  'gmtoffset': -14400,
#  'timezone': 'EDT',
#  'exchangeTimezoneName': 'America/New_York',
#  'regularMarketPrice': 139.45,
#  'fiftyTwoWeekHigh': 140.95,
#  'fiftyTwoWeekLow': 138.41,
#  'regularMarketDayHigh': 140.95,
#  'regularMarketDayLow': 138.41,
#  'regularMarketVolume': 1097529,
#  'chartPreviousClose': 31.474,
#  'priceHint': 2,
#  'currentTradingPeriod': {'pre': {'timezone': 'EDT',
#    'start': 1714723200,
#    'end': 1714743000,
#    'gmtoffset': -14400},
#   'regular': {'timezone': 'EDT',
#    'start': 1714743000,
#    'end': 1714766400,
#    'gmtoffset': -14400},
#   'post': {'timezone': 'EDT',
#    'start': 1714766400,
#    'end': 1714780800,
#    'gmtoffset': -14400}},
#  'dataGranularity': '1d',
#  'range': '',
#  'validRanges': ['1d',
# ...

# %%
# show actions (dividends, splits, capital gains)
a.actions
#a.dividends
#a.splits
#a.capital_gains  # only for mutual funds & etfs
# Out:
#                            Dividends  Stock Splits
# Date
# 2006-11-01 00:00:00-05:00   1.471388         0.000
# 2012-03-30 00:00:00-04:00   0.071531         0.000
# 2012-06-29 00:00:00-04:00   0.071531         0.000
# 2012-09-28 00:00:00-04:00   0.071531         0.000
# 2012-12-27 00:00:00-05:00   0.071531         0.000
# 2013-03-28 00:00:00-04:00   0.085837         0.000
# 2013-06-28 00:00:00-04:00   0.085837         0.000
# 2013-09-27 00:00:00-04:00   0.085837         0.000
# 2013-12-27 00:00:00-05:00   0.094421         0.000
# 2014-04-09 00:00:00-04:00   0.094421         0.000
# 2014-06-27 00:00:00-04:00   0.094421         0.000
# 2014-09-26 00:00:00-04:00   0.094421         0.000
# 2014-11-03 00:00:00-05:00   0.000000         1.398
# 2015-01-02 00:00:00-05:00   0.100000         0.000
# 2015-03-27 00:00:00-04:00   0.100000         0.000
# 2015-06-26 00:00:00-04:00   0.100000         0.000
# 2015-09-25 00:00:00-04:00   0.100000         0.000
# ...

# %%
# show share count
a.get_shares_full(start="2022-01-01", end=None)
# Out:
# 2022-02-04 00:00:00-05:00    307219008
# 2022-02-05 00:00:00-05:00    300366016
# 2022-02-11 00:00:00-05:00    300366016
# 2022-03-07 00:00:00-05:00    300112992
# 2022-03-15 00:00:00-04:00    306535008
#                                ...
# 2024-04-25 00:00:00-04:00    293055008
# 2024-04-25 00:00:00-04:00    296700000
# 2024-04-30 00:00:00-04:00    293055008
# 2024-05-01 00:00:00-04:00    293055008
# 2024-05-02 00:00:00-04:00    293055008
# Length: 138, dtype: int64

# %%
# show financials:
# - income statement
a.income_stmt
a.quarterly_income_stmt
# - balance sheet
a.balance_sheet
a.quarterly_balance_sheet
# - cash flow statement
a.cashflow
a.quarterly_cashflow
# see `Ticker.get_income_stmt()` for more options
# Out:
#                                                   2024-01-31    2023-10-31  \
# Free Cash Flow                                   395000000.0   432000000.0
# Repurchase Of Capital Stock                              0.0   -80000000.0
# Repayment Of Debt                               -180000000.0           0.0
# Issuance Of Debt                                         0.0   -20000000.0
# Capital Expenditure                              -90000000.0   -84000000.0
# Interest Paid Supplemental Data                   14000000.0    29000000.0
# Income Tax Paid Supplemental Data                 24000000.0    56000000.0
# End Cash Position                               1750000000.0  1593000000.0
# Beginning Cash Position                         1593000000.0  1332000000.0
# Effect Of Exchange Rate Changes                    7000000.0   -14000000.0
# Changes In Cash                                  150000000.0   275000000.0
# ...

# %%
# show holders
a.major_holders
a.institutional_holders
#a.mutualfund_holders
#a.insider_transactions
#a.insider_purchases
#a.insider_roster_holders
# Out:
#   Date Reported                                     Holder  pctHeld    Shares  \
# 0    2023-06-30                             Blackrock Inc.   0.1089  31853176
# 1    2023-06-30                         Vanguard Group Inc   0.0861  25199676
# 2    2023-06-30                   State Street Corporation   0.0452  13214595
# 3    2023-06-30       Massachusetts Financial Services Co.   0.0377  11037240
# 4    2023-06-30  T. Rowe Price Investment Management, Inc.   0.0341   9967550
# 5    2023-06-30           Wellington Management Group, LLP   0.0299   8736392
# 6    2023-06-30              Price (T.Rowe) Associates Inc   0.0275   8053975
# 7    2023-06-30                 Pictet Asset Management SA   0.0227   6644015
# 8    2023-06-30              Geode Capital Management, LLC   0.0218   6378218
# 9    2023-06-30                             Morgan Stanley   0.0164   4793914
#
#         Value
# 0  3830344414
# 1  3030261039
# 2  1589055048
# 3  1327228110
# 4  1198597887
# 5  1050551138
# ...

# %% [markdown]
# <h1> Downloading the stock data </h1>

# %%
# Prepare the Data
df['date'] = pd.to_datetime(df['date'], format='ISO8601')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Prepare the Data
# ----> 2 df['date'] = pd.to_datetime(df['date'], format='ISO8601')
#
# NameError: name 'pd' is not defined

# %%
# Group the data by stock symbol and aggregate the minimum and maximum dates
grouped_data = df.groupby('stock')['date'].agg(['min', 'max'])
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File F:\code\installation\Lib\site-packages\pandas\core\groupby\groupby.py:1490, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1489 try:
# -> 1490     result = self.grouper._cython_operation(
#    1491         "aggregate",
#    1492         values,
#    1493         how,
#    1494         axis=data.ndim - 1,
#    1495         min_count=min_count,
#    1496         **kwargs,
#    1497     )
#    1498 except NotImplementedError:
#    1499     # generally if we have numeric_only=False
#    1500     # and non-applicable functions
#    1501     # try to python agg
#    1502     # TODO: shouldn't min_count matter?
#
# File F:\code\installation\Lib\site-packages\pandas\core\groupby\ops.py:959, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     958 ngroups = self.ngroups
# ...

# %%
# Display the date range for each stock
print("Date Ranges for Each Stock:")
print(grouped_data)
# Out:
# Date Ranges for Each Stock:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 3
#       1 # Display the date range for each stock
#       2 print("Date Ranges for Each Stock:")
# ----> 3 print(grouped_data)
#
# NameError: name 'grouped_data' is not defined

# %%
# Initialize an empty DataFrame to store all stock data
all_stock_data1 = pd.DataFrame()

# %%
# Loop through each group (stock symbol) in grouped_data
for stock_symbol, date_range in grouped_data.iterrows():
    start_date = date_range['min']
    end_date = date_range['max']
    
    try:
        # Download stock data
        stock_data = yf.download(stock_symbol, start=start_date, end=end_date)
        
        # Add stock symbol as a column in the DataFrame
        stock_data['Symbol'] = stock_symbol
        
        # Append stock data to the DataFrame containing all stock data
        all_stock_data1 = pd.concat([all_stock_data1, stock_data])
        
        print("Stock data for", stock_symbol, "downloaded successfully.")
    except Exception as e:
        print("Failed to download stock data for", stock_symbol, ":", str(e))

# Save all stock data to a CSV file
all_stock_data1.to_csv('all_stock_data1.csv')
